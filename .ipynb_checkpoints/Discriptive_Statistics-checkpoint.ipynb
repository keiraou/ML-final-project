# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pylab as pl

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline 
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %%
import data_explore
import pipeline_tree
import pipeline_classification

# %% [markdown]
# # Create Dataframe, Features and Targets

# %%
# All data

FILES = ['cleaned_data/cambodia_2014_cleaned.csv', 
         'cleaned_data/Maldives_2016_cleaned.csv', 
         'cleaned_data/Nepal_2016_cleaned.csv',
         'cleaned_data/Pakistan_2017_cleaned.csv',
         'cleaned_data/Philippines_2017_cleaned.csv']

COUNTRY_DATA = {
    'Cambodia': 'cleaned_data/cambodia_2014_cleaned.csv', 
    'Maldives': 'cleaned_data/Maldives_2016_cleaned.csv', 
    'Nepal': 'cleaned_data/Nepal_2016_cleaned.csv',
    'Pakistan': 'cleaned_data/Pakistan_2017_cleaned.csv',
    'Philippines': 'cleaned_data/Philippines_2017_cleaned.csv'   
}

def create_df_each_country():
    
    df_dic = {}
    for country, file in COUNTRY_DATA.items():
        df = pd.read_csv(file)
        df_dic[country] = df
        
        if 'country' in df.columns:
            df.drop(columns=['country'],inplace=True)
    return df_dic

def create_df_all_countries():
    
    df_dic={}
    for country, file in COUNTRY_DATA.items():
        df = pd.read_csv(file)
        df['country'] = country        
        df_dic[country] = df
                 
    df = pd.concat(df_dic.values(), ignore_index=True)
    return df

#create dataframe containing all 5 countries
df = create_df_all_countries()

#create dataframe for each country

df_dic = create_df_each_country()

df_Cambodia = df_dic['Cambodia']
df_Maldives = df_dic['Maldives']
df_Nepal = df_dic['Nepal']
df_Pakistan = df_dic['Pakistan']
df_Philippines = df_dic['Philippines']

# %% [markdown]
# # Visualize None Values

# %%
#All features and targets

NUMERIC_FEATURES = ['age','education','num_household','num_child',
                    'partner_edu','if_own_house','if_employment_current']
CATGORICAL_FEATURES = ['if_urban','wealth_index','if_earn_more','sex_head_household', 
              'partner_ideal_child','money_decide_person']
FEATURES = NUMERIC_FEATURES + CATGORICAL_FEATURES
TARGET_LST = ['if_emo_vio', 'if_phy_vio', 'if_sex_vio', 'if_vio']

# %%
#Get propotions of None values

def missing_propotion(df):
    
        prop_dic={}
    for col in df:
        val_prop = df[col].isna().astype(int).sum()/df.shape[0]
        if val_prop !=0:
            prop_dic[col] = [val_prop]
        
    return prop_dic

features_none_prop = missing_propotion(df[FEATURES])
target_none_prop = missing_propotion(df[TARGET_LST])

features_none_df = pd.DataFrame.from_dict(features_none_prop, orient='index', \
                                          columns=['None Value Proportion']).reset_index()
features_none_df.columns = ['Features', 'None Value Proportion']

target_none_df = pd.DataFrame.from_dict(target_none_prop, orient='index', \
                                        columns=['None Value Proportion']).reset_index()
target_none_df.columns = ['Target', 'None Value Proportion']

# %%
# Print out the None values in features

features_none_df
# Out:
#               Features  None Value Proportion
# 0          partner_edu               0.000175
# 1         if_earn_more               0.604648
# 2  partner_ideal_child               0.081713
# 3  money_decide_person               0.604648

# %%
# Print out the None values in targets

target_none_df
# Out:
#        Target  None Value Proportion
# 0  if_emo_vio               0.536079
# 1  if_phy_vio               0.536114
# 2  if_sex_vio               0.536096
# 3      if_vio               0.536131

# %%
# Visualize None valuse

plt.figure(figsize=(1,1), dpi=180)
sns.barplot(x="None Value Proportion", y = 'Features', palette="ch:s=.25,rot=-.25", \
                data = features_none_df).set_title('''Proportion of None Values in Features''')
plt.show()

# %%
# Visualize None values

plt.figure(figsize=(1,1), dpi=180)
sns.barplot(x="None Value Proportion", y = 'Target', palette="ch:s=.25,rot=-.25", \
                data = target_none_df).set_title('''Proportion of None Values in Targets''')
plt.show()

# %%
# visulize the None value distribution

pipeline_classification.plot_df_na(df[FEATURES + TARGET_LST])
plt.show()

# %% [markdown]
# # Visulize Correlations

# %%
# Show correlations

data_explore.generate_corr_graph(df[FEATURES + TARGET_LST])
# Out:
# <style  type="text/css" >
# #T_9bb37_row0_col0,#T_9bb37_row1_col1,#T_9bb37_row2_col2,#T_9bb37_row3_col3,#T_9bb37_row4_col4,#T_9bb37_row5_col5,#T_9bb37_row6_col6,#T_9bb37_row7_col7,#T_9bb37_row8_col8,#T_9bb37_row9_col9{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_9bb37_row0_col1,#T_9bb37_row2_col9{
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }#T_9bb37_row0_col2,#T_9bb37_row9_col0{
#             background-color:  #e3eef8;
#             color:  #000000;
#         }#T_9bb37_row0_col3{
#             background-color:  #3686c0;
#             color:  #000000;
#         }#T_9bb37_row0_col4{
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }#T_9bb37_row0_col5{
#             background-color:  #b8d5ea;
#             color:  #000000;
#         }#T_9bb37_row0_col6,#T_9bb37_row1_col2,#T_9bb37_row4_col6,#T_9bb37_row5_col8{
#             background-color:  #e5eff9;
#             color:  #000000;
#         }#T_9bb37_row0_col7{
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }#T_9bb37_row0_col8,#T_9bb37_row2_col8{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }#T_9bb37_row0_col9{
#             background-color:  #deebf7;
#             color:  #000000;
#         }#T_9bb37_row1_col0,#T_9bb37_row1_col3,#T_9bb37_row1_col6,#T_9bb37_row1_col7,#T_9bb37_row1_col8,#T_9bb37_row1_col9,#T_9bb37_row2_col0,#T_9bb37_row2_col4,#T_9bb37_row2_col5,#T_9bb37_row3_col1,#T_9bb37_row4_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_9bb37_row1_col4{
#             background-color:  #c7dbef;
#             color:  #000000;
#         }#T_9bb37_row1_col5,#T_9bb37_row3_col9{
#             background-color:  #ccdff1;
#             color:  #000000;
#         }#T_9bb37_row2_col1{
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }#T_9bb37_row2_col3{
#             background-color:  #94c4df;
#             color:  #000000;
#         }#T_9bb37_row2_col6{
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }#T_9bb37_row2_col7{
#             background-color:  #cde0f1;
#             color:  #000000;
#         }#T_9bb37_row3_col0{
#             background-color:  #4a98c9;
#             color:  #000000;
#         }#T_9bb37_row3_col2{
#             background-color:  #a6cee4;
#             color:  #000000;
#         }#T_9bb37_row3_col4{
#             background-color:  #c2d9ee;
#             color:  #000000;
#         }#T_9bb37_row3_col5,#T_9bb37_row7_col5{
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }#T_9bb37_row3_col6{
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }#T_9bb37_row3_col7{
#             background-color:  #c3daee;
#             color:  #000000;
#         }#T_9bb37_row3_col8{
#             background-color:  #dfecf7;
#             color:  #000000;
#         }#T_9bb37_row4_col0{
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }#T_9bb37_row4_col1{
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }#T_9bb37_row4_col3{
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }#T_9bb37_row4_col5{
#             background-color:  #9fcae1;
#             color:  #000000;
#         }#T_9bb37_row4_col7{
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_9bb37_row4_col8{
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }#T_9bb37_row4_col9,#T_9bb37_row6_col0,#T_9bb37_row7_col1{
#             background-color:  #e2edf8;
#             color:  #000000;
#         }#T_9bb37_row5_col0,#T_9bb37_row7_col2,#T_9bb37_row9_col2{
#             background-color:  #c9ddf0;
#             color:  #000000;
#         }#T_9bb37_row5_col1{
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }#T_9bb37_row5_col2{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }#T_9bb37_row5_col3{
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }#T_9bb37_row5_col4{
#             background-color:  #97c6df;
#             color:  #000000;
#         }#T_9bb37_row5_col6{
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }#T_9bb37_row5_col7{
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }#T_9bb37_row5_col9,#T_9bb37_row8_col0{
#             background-color:  #e3eef9;
#             color:  #000000;
#         }#T_9bb37_row6_col1{
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }#T_9bb37_row6_col2{
#             background-color:  #cadef0;
#             color:  #000000;
#         }#T_9bb37_row6_col3{
#             background-color:  #aed1e7;
#             color:  #000000;
#         }#T_9bb37_row6_col4{
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }#T_9bb37_row6_col5{
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }#T_9bb37_row6_col7{
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }#T_9bb37_row6_col8{
#             background-color:  #afd1e7;
#             color:  #000000;
#         }#T_9bb37_row6_col9{
#             background-color:  #08519c;
#             color:  #f1f1f1;
#         }#T_9bb37_row7_col0{
#             background-color:  #e4eff9;
#             color:  #000000;
#         }#T_9bb37_row7_col3{
#             background-color:  #aacfe5;
#             color:  #000000;
#         }#T_9bb37_row7_col4,#T_9bb37_row9_col1,#T_9bb37_row9_col5{
#             background-color:  #dae8f6;
#             color:  #000000;
#         }#T_9bb37_row7_col6{
#             background-color:  #69add5;
#             color:  #000000;
#         }#T_9bb37_row7_col8{
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }#T_9bb37_row7_col9{
#             background-color:  #2676b8;
#             color:  #000000;
#         }#T_9bb37_row8_col1{
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }#T_9bb37_row8_col2,#T_9bb37_row8_col4{
#             background-color:  #d2e3f3;
#             color:  #000000;
#         }#T_9bb37_row8_col3{
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }#T_9bb37_row8_col5{
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }#T_9bb37_row8_col6,#T_9bb37_row9_col3{
#             background-color:  #abd0e6;
#             color:  #000000;
#         }#T_9bb37_row8_col7{
#             background-color:  #84bcdb;
#             color:  #000000;
#         }#T_9bb37_row8_col9{
#             background-color:  #89bedc;
#             color:  #000000;
#         }#T_9bb37_row9_col4{
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }#T_9bb37_row9_col6{
#             background-color:  #09529d;
#             color:  #f1f1f1;
#         }#T_9bb37_row9_col7{
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }#T_9bb37_row9_col8{
#             background-color:  #95c5df;
#             color:  #000000;
#         }</style><table id="T_9bb37_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >education</th>        <th class="col_heading level0 col2" >num_household</th>        <th class="col_heading level0 col3" >num_child</th>        <th class="col_heading level0 col4" >if_own_house</th>        <th class="col_heading level0 col5" >if_employment_current</th>        <th class="col_heading level0 col6" >if_emo_vio</th>        <th class="col_heading level0 col7" >if_phy_vio</th>        <th class="col_heading level0 col8" >if_sex_vio</th>        <th class="col_heading level0 col9" >if_vio</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9bb37_level0_row0" class="row_heading level0 row0" >age</th>
#                         <td id="T_9bb37_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_9bb37_row0_col1" class="data row0 col1" >-0.105109</td>

# %% [markdown]
# # Summary Statistics

# %%
df.groupby('country').mean()
# Out:
#                Unnamed: 0    year        age  education  if_union  \
# country
# Cambodia      8819.868529  2014.0  32.980802   5.084333       1.0
# Maldives      3874.259253  2016.0  33.557473   8.666370       1.0
# Nepal         6405.266963  2016.0  31.715166   4.341175       1.0
# Pakistan      7535.740174  2017.0  32.118191   4.462971       1.0
# Philippines  12901.733635  2017.0  34.520104  10.297443       1.0
#
#              wealth_index_code  if_own_house  if_own_land  \
# country
# Cambodia              2.161553      0.761313     0.666781
# Maldives              1.411032      0.199644     1.000000
# Nepal                 1.901252      0.087036     0.125404
# Pakistan              2.005241      0.026686     0.019032
# Philippines           1.654969      0.527290     0.190936
#
#              if_employment_current  num_household  num_child  if_emo_vio  \
# country
# Cambodia                  0.725917       5.468804   2.594446    0.215017
# Maldives                  0.407829       6.867438   2.265125    0.161384
# Nepal                     0.606926       5.459612   2.532916    0.123247
# Pakistan                  0.129499       8.459937   3.353882    0.302144
# Philippines               0.506701       5.409906   2.829136    0.205831
#
#              if_phy_vio  if_phy_vio_severe  if_sex_vio    if_vio   num_vio
# country
# Cambodia       0.141793           0.058641    0.040645  0.253491  0.397456
# Maldives       0.096701           0.025550    0.010349  0.207956  0.268435
# Nepal          0.216019           0.097087    0.074703  0.252427  0.413970
# Pakistan       0.242745           0.064834    0.043138  0.365220  0.587834
# Philippines    0.103994           0.040016    0.038738  0.242412  0.348562

# %%
df.groupby('country').median()
# Out:
#              Unnamed: 0    year   age  education  if_union  wealth_index_code  \
# country
# Cambodia         8867.5  2014.0  32.0        5.0       1.0                2.0
# Maldives         3897.5  2016.0  33.0       10.0       1.0                1.0
# Nepal            6427.0  2016.0  31.0        4.0       1.0                2.0
# Pakistan         7556.5  2017.0  32.0        0.0       1.0                2.0
# Philippines     13052.0  2017.0  35.0       11.0       1.0                1.0
#
#              if_own_house  if_own_land  if_employment_current  num_household  \
# country
# Cambodia              1.0          1.0                    1.0            5.0
# Maldives              0.0          1.0                    0.0            6.0
# Nepal                 0.0          0.0                    1.0            5.0
# Pakistan              0.0          0.0                    0.0            7.0
# Philippines           1.0          0.0                    1.0            5.0
#
#              num_child  if_emo_vio  if_phy_vio  if_phy_vio_severe  if_sex_vio  \
# country
# Cambodia           2.0         0.0         0.0                0.0         0.0
# Maldives           2.0         0.0         0.0                0.0         0.0
# Nepal              2.0         0.0         0.0                0.0         0.0
# Pakistan           3.0         0.0         0.0                0.0         0.0
# Philippines        2.0         0.0         0.0                0.0         0.0
#
#              if_vio  num_vio
# country
# Cambodia        0.0      0.0
# Maldives        0.0      0.0
# Nepal           0.0      0.0
# Pakistan        0.0      0.0
# Philippines     0.0      0.0

# %%
df.groupby('country').std()
# Out:
#               Unnamed: 0  year       age  education  if_union  \
# country
# Cambodia     5118.800480   0.0  8.585149   3.820600       0.0
# Maldives     2159.460860   0.0  7.780427   3.534475       0.0
# Nepal        3708.814759   0.0  8.817443   4.314134       0.0
# Pakistan     4351.579758   0.0  8.284005   5.243966       0.0
# Philippines  7279.805673   0.0  8.491876   3.567218       0.0
#
#              wealth_index_code  if_own_house  if_own_land  \
# country
# Cambodia              1.471377      0.426299     0.471384
# Maldives              1.155511      0.399768     0.000000
# Nepal                 1.390067      0.281901     0.331193
# Pakistan              1.413862      0.161170     0.136642
# Philippines           1.388018      0.499271     0.393051
#
#              if_employment_current  num_household  num_child  if_emo_vio  \
# country
# Cambodia                  0.446070       2.197337   1.878063    0.410898
# Maldives                  0.491475       3.389268   1.717500    0.367944
# Nepal                     0.488458       2.801088   1.778769    0.328765
# Pakistan                  0.335763       4.605522   2.491913    0.459245
# Philippines               0.499971       2.267667   2.044634    0.404323
#
#              if_phy_vio  if_phy_vio_severe  if_sex_vio    if_vio   num_vio
# country
# Cambodia       0.348892           0.234988    0.197498  0.435077  0.758126
# Maldives       0.295598           0.157813    0.101220  0.405911  0.577032
# Nepal          0.411583           0.296117    0.262948  0.434464  0.803546
# Pakistan       0.428797           0.246263    0.203194  0.481552  0.865615
# Philippines    0.305264           0.196005    0.192978  0.428559  0.694533

# %%
#Plot the number of violence category distributions for different countries

fig, ax = plt.subplots(figsize=(10,6))
sns.distplot(df['if_vio'][df['country']=='Cambodia'], bins=20, kde=True, color='navy', label='Cambodia')
sns.distplot(df['if_vio'][df['country']=='Maldives'], bins=20, kde=True, color='red', label='Maldives')
sns.distplot(df['if_vio'][df['country']=='Nepal'], bins=20, kde=True, color='blue', label='Nepal')
sns.distplot(df['if_vio'][df['country']=='Pakistan'], bins=20, kde=True, color='green', label='Pakistan')
sns.distplot(df['if_vio'][df['country']=='Philippines'], bins=20, kde=True, color='purple', label='Philippines')

plt.xlabel('Violence')
plt.ylabel('Density')
plt.title('Violence Distribution for Different Countries', size=15, style='italic')
plt.legend(loc='upper left')
plt.show()

#fig.savefig('if_vio_distribution.png')

# %%
#Plot violence distributions for different countries

fig, ax = plt.subplots(figsize=(10,6))
sns.distplot(df['num_vio'][df['country']=='Cambodia'], bins=20, kde=True, color='navy', label='Cambodia')
sns.distplot(df['num_vio'][df['country']=='Maldives'], bins=20, kde=True, color='red', label='Maldives')
sns.distplot(df['num_vio'][df['country']=='Nepal'], bins=20, kde=True, color='blue', label='Nepal')
sns.distplot(df['num_vio'][df['country']=='Pakistan'], bins=20, kde=True, color='green', label='Pakistan')
sns.distplot(df['num_vio'][df['country']=='Philippines'], bins=20, kde=True, color='purple', label='Philippines')

plt.xlabel('Number of Violence Categories')
plt.ylabel('Density')
plt.title('Violence Category Distribution for Different Countries', size=15, style='italic')
plt.legend(loc='upper left')
plt.show()

#fig.savefig('num_vio_distribution.png')
