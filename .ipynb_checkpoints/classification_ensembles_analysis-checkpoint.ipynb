# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pylab as pl

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline 
from sklearn import metrics

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pipeline_classification

# %% [markdown]
# # CREATE DATAFRAME

# %%
FILES = ['cleaned_data/cambodia_2014_cleaned.csv', 
         'cleaned_data/Maldives_2016_cleaned.csv', 
         'cleaned_data/Nepal_2016_cleaned.csv',
         'cleaned_data/Pakistan_2017_cleaned.csv',
         'cleaned_data/Philippines_2017_cleaned.csv']

COUNTRY_DATA = {
    'Cambodia': 'cleaned_data/cambodia_2014_cleaned.csv', 
    'Maldives': 'cleaned_data/Maldives_2016_cleaned.csv', 
    'Nepal': 'cleaned_data/Nepal_2016_cleaned.csv',
    'Pakistan': 'cleaned_data/Pakistan_2017_cleaned.csv',
    'Philippines': 'cleaned_data/Philippines_2017_cleaned.csv'   
}

# %%
def create_df_each_country():
    
    df_dic = {}
    for country, file in COUNTRY_DATA.items():
        df = pd.read_csv(file)
        df_dic[country] = df
        
        if 'country' in df.columns:
            df.drop(columns=['country'],inplace=True)
    return df_dic

# %%
def create_df_all_countries():
    
    for country, file in COUNTRY_DATA.items():
        df = pd.read_csv(file)
        df['country'] = country        
        df_dic[country] = df
                 
    df = pd.concat(df_dic.values(), ignore_index=True)
    return df

# %%
#create dataframe containing all 5 countries
df = create_df_all_countries()

# %%
#create dataframe for each country

df_dic = create_df_each_country()

df_Cambodia = df_dic['Cambodia']
df_Maldives = df_dic['Maldives']
df_Nepal = df_dic['Nepal']
df_Pakistan = df_dic['Pakistan']
df_Philippines = df_dic['Philippines']

# %% [markdown]
# # CREATE FETURES AND TAGETS

# %%
#need hot-code
need_one_hot=['if_urban','wealth_index','if_earn_more','sex_head_household', \
              'partner_ideal_child','money_decide_person','country']

#already dummy
dummy=['if_own_house','if_employment_current']

#need normalize
need_normalize=['age','education','num_household','num_child','partner_edu']

#all features to be analyzed
features_col = need_normalize + dummy + need_one_hot

#all targets to be analyzed
target_col=['if_emo_vio', 'if_phy_vio', 'if_sex_vio', 'if_vio']

# %% [markdown]
# # Analyze all countries by LogisticRegression

# %%
pipeline_classification.plot_df_na(df)

# %%
# drop observations that have None in targets and categorical attributes

pipeline_classification.drop_na(df, target_col+need_one_hot+dummy)

# %%
# create dataframes for features and targets

features, target = pipeline_classification.preprocess_data(df, features_col, target_col, need_one_hot)

# %%
# split data

X_train, X_test, y_train, y_test = pipeline_classification.split_data(features, target, need_normalize)

# %%
# impute None values

X_train, X_test = pipeline_classification.impute_missing_median(X_train, X_test)

# %%
y_train1 = y_train['if_emo_vio']
y_train2 = y_train['if_phy_vio']
y_train3 = y_train['if_sex_vio']
y_train4 = y_train['if_vio']

y_test1 = y_test['if_emo_vio']
y_test2 = y_test['if_phy_vio']
y_test3 = y_test['if_sex_vio']
y_test4 = y_test['if_vio']

# %% [markdown]
# ## Target 1: if have emotional violence

# %%
# Use SMOTE to deal with inbalanced data

result, best_model = pipeline_classification.train_logistic_regression_SMOTE(X_train, y_train1,'All', 'if_emo_vio')

# %%
result
# Out:
#   country      target               model  \
# 0     All  if_emo_vio  LogisticRegression
# 1     All  if_emo_vio  LogisticRegression
# 2     All  if_emo_vio  LogisticRegression
# 3     All  if_emo_vio  LogisticRegression
# 4     All  if_emo_vio  LogisticRegression
#
#                                               params        f1  accuracy  \
# 0  {'logisticregression__C': 0.01, 'logisticregre...  0.341284  0.699944
# 1  {'logisticregression__C': 0.1, 'logisticregres...  0.250019  0.759409
# 2  {'logisticregression__C': 1, 'logisticregressi...  0.196120  0.779593
# 3  {'logisticregression__C': 10, 'logisticregress...  0.184464  0.781640
# 4  {'logisticregression__C': 100, 'logisticregres...  0.186921  0.781912
#
#    precision    recall   roc_auc
# 0   0.297570  0.400409  0.633795
# 1   0.318910  0.206895  0.625862
# 2   0.338638  0.138624  0.623778
# 3   0.339024  0.127366  0.623599
# 4   0.340986  0.129474  0.623878

# %%
best_model
# Out:
# LogisticRegression(C=0.01, random_state=0)

# %%
result1, best_model1 = pipeline_classification.train_logistic_regression(X_train, y_train1, 'All', 'if_emo_vio')

# %%
result1
# Out:
#   country      target               model                        params  \
# 0     All  if_emo_vio  LogisticRegression  {'C': 0.01, 'penalty': 'l2'}
# 1     All  if_emo_vio  LogisticRegression   {'C': 0.1, 'penalty': 'l2'}
# 2     All  if_emo_vio  LogisticRegression     {'C': 1, 'penalty': 'l2'}
# 3     All  if_emo_vio  LogisticRegression    {'C': 10, 'penalty': 'l2'}
# 4     All  if_emo_vio  LogisticRegression   {'C': 100, 'penalty': 'l2'}
#
#          f1  accuracy  precision    recall   roc_auc
# 0  0.002797  0.806056   0.200000  0.001408  0.643090
# 1  0.008249  0.804829   0.261667  0.004220  0.644100
# 2  0.011027  0.804829   0.406667  0.005629  0.643770
# 3  0.011008  0.804556   0.373333  0.005629  0.643898
# 4  0.010998  0.804420   0.356667  0.005629  0.643922

# %%
best_model1
# Out:
# LogisticRegression(C=1, random_state=0)

# %% [raw]
# It's better to use the best model trained from the SMOTE LogisticRegression(C=0.01, random_state=0)

# %%
pipeline_classification.evaluate_test(best_model, X_test, y_test1, 0.5)
# Out:
# {'f1': 0.3555900621118012,
#  'accuracy': 0.5474372955288986,
#  'precision': 0.24972737186477645,
#  'recall': 0.6172506738544474,
#  'roc_auc': 0.573492049162357,
#  'model_object': LogisticRegression(C=0.01, random_state=0)}

# %%
coeffs = pipeline_classification.get_important_attributes(X_train.columns, best_model)
coeffs
# Out:
#                                             predictor  coefficient  \
# 14                        if_earn_more_about the same    -0.973984
# 13                               wealth_index_richest    -0.929166
# 12                                wealth_index_richer    -0.801109
# 29                                      country_Nepal    -0.791826
# 20                 partner_ideal_child_both want same    -0.777822
# 25  money_decide_person_respondent and husband/par...    -0.728807
# 22             partner_ideal_child_husband wants more    -0.724609
# 9                                 wealth_index_middle    -0.723828
# 18                          sex_head_household_female    -0.711105
# 17                         if_earn_more_more than him    -0.675836
# 8                                      if_urban_urban    -0.587262
# 16                         if_earn_more_less than him    -0.585791
# 28                                   country_Maldives    -0.559738
# 10                                wealth_index_poorer    -0.546279
# 11                               wealth_index_poorest    -0.535111
# 23          money_decide_person_husband/partner alone    -0.531114
# 19                            sex_head_household_male    -0.530885
# 7                                      if_urban_rural    -0.512548
# 24               money_decide_person_respondent alone    -0.473544
# 21            partner_ideal_child_husband wants fewer    -0.441560
# 15  if_earn_more_husband/partner doesn't bring in ...    -0.364904
# 30                                   country_Pakistan    -0.331242
# 27                                   country_Cambodia    -0.309574
# 6                               if_employment_current    -0.303973
# 5                                        if_own_house    -0.299743
# 3                                           num_child     0.256508
# 0                                                 age    -0.124070
# 1                                           education    -0.119726
# 2                                       num_household    -0.100352
# 26                   money_decide_person_someone else    -0.089196
# 4                                         partner_edu    -0.088969
# 31                                country_Philippines    -0.055996
#
#     abs_coeffient
# 14       0.973984
# 13       0.929166
# 12       0.801109
# 29       0.791826
# 20       0.777822
# 25       0.728807
# 22       0.724609
# 9        0.723828
# 18       0.711105
# 17       0.675836
# 8        0.587262
# 16       0.585791
# 28       0.559738
# 10       0.546279
# 11       0.535111
# 23       0.531114
# 19       0.530885
# 7        0.512548
# 24       0.473544
# 21       0.441560
# 15       0.364904
# 30       0.331242
# 27       0.309574
# 6        0.303973
# 5        0.299743
# 3        0.256508
# 0        0.124070
# 1        0.119726
# 2        0.100352
# 26       0.089196
# 4        0.088969
# 31       0.055996

# %%
pipeline_classification.plot_top10_attributes(coeffs, best_model)

# %% [markdown]
# ## Target 2: if have physical violence

# %%
# Use SMOTE to deal with inbalanced data

result, best_model = pipeline_classification.train_logistic_regression_SMOTE(X_train, y_train2,'All', 'if_phy_vio')

# %%
result
# Out:
#   country      target               model  \
# 0     All  if_phy_vio  LogisticRegression
# 1     All  if_phy_vio  LogisticRegression
# 2     All  if_phy_vio  LogisticRegression
# 3     All  if_phy_vio  LogisticRegression
# 4     All  if_phy_vio  LogisticRegression
#
#                                               params        f1  accuracy  \
# 0  {'logisticregression__C': 0.01, 'logisticregre...  0.282977  0.767322
# 1  {'logisticregression__C': 0.1, 'logisticregres...  0.224562  0.843971
# 2  {'logisticregression__C': 1, 'logisticregressi...  0.165025  0.859792
# 3  {'logisticregression__C': 10, 'logisticregress...  0.151207  0.859792
# 4  {'logisticregression__C': 100, 'logisticregres...  0.145892  0.859656
#
#    precision    recall   roc_auc
# 0   0.232241  0.363090  0.664174
# 1   0.304806  0.178845  0.654272
# 2   0.341502  0.109864  0.650554
# 3   0.330005  0.099100  0.649410
# 4   0.326883  0.094799  0.649302

# %%
best_model
# Out:
# LogisticRegression(C=0.01, random_state=0)

# %%
result1, best_model1 = pipeline_classification.train_logistic_regression(X_train, y_train2, 'All', 'if_phy_vio')

# %%
result1
# Out:
#   country      target               model                        params  \
# 0     All  if_phy_vio  LogisticRegression  {'C': 0.01, 'penalty': 'l2'}
# 1     All  if_phy_vio  LogisticRegression   {'C': 0.1, 'penalty': 'l2'}
# 2     All  if_phy_vio  LogisticRegression     {'C': 1, 'penalty': 'l2'}
# 3     All  if_phy_vio  LogisticRegression    {'C': 10, 'penalty': 'l2'}
# 4     All  if_phy_vio  LogisticRegression   {'C': 100, 'penalty': 'l2'}
#
#          f1  accuracy  precision    recall   roc_auc
# 0  0.004255  0.873568   0.200000  0.002151  0.675577
# 1  0.012633  0.873568   0.316667  0.006463  0.674768
# 2  0.014693  0.873432   0.333333  0.007539  0.674138
# 3  0.014693  0.873432   0.333333  0.007539  0.673481
# 4  0.014693  0.873432   0.333333  0.007539  0.673400

# %%
best_model1
# Out:
# LogisticRegression(C=1, random_state=0)

# %% [raw]
# It's better to use the best model trained from the SMOTE LogisticRegression(C=0.01, random_state=0)

# %%
pipeline_classification.evaluate_test(best_model, X_test, y_test2, 0.5)
# Out:
# {'f1': 0.28571428571428575,
#  'accuracy': 0.544711014176663,
#  'precision': 0.1821155943293348,
#  'recall': 0.6626984126984127,
#  'roc_auc': 0.594307487006602,
#  'model_object': LogisticRegression(C=0.01, random_state=0)}

# %%
coeffs = pipeline_classification.get_important_attributes(X_train.columns, best_model)
coeffs
# Out:
#                                             predictor  coefficient  \
# 20                 partner_ideal_child_both want same    -1.031115
# 13                               wealth_index_richest    -1.011025
# 14                        if_earn_more_about the same    -1.004885
# 25  money_decide_person_respondent and husband/par...    -0.989633
# 12                                wealth_index_richer    -0.941920
# 18                          sex_head_household_female    -0.840583
# 9                                 wealth_index_middle    -0.814653
# 22             partner_ideal_child_husband wants more    -0.814487
# 10                                wealth_index_poorer    -0.808649
# 21            partner_ideal_child_husband wants fewer    -0.733161
# 16                         if_earn_more_less than him    -0.719995
# 17                         if_earn_more_more than him    -0.711268
# 8                                      if_urban_urban    -0.709860
# 7                                      if_urban_rural    -0.708585
# 11                               wealth_index_poorest    -0.657641
# 23          money_decide_person_husband/partner alone    -0.652304
# 28                                   country_Maldives    -0.647462
# 27                                   country_Cambodia    -0.607680
# 24               money_decide_person_respondent alone    -0.588499
# 30                                   country_Pakistan    -0.538736
# 31                                country_Philippines    -0.462065
# 19                            sex_head_household_male    -0.441827
# 15  if_earn_more_husband/partner doesn't bring in ...    -0.439172
# 5                                        if_own_house    -0.403288
# 6                               if_employment_current    -0.350789
# 29                                      country_Nepal    -0.329259
# 3                                           num_child     0.258221
# 1                                           education    -0.220539
# 2                                       num_household    -0.210803
# 4                                         partner_edu    -0.167712
# 0                                                 age    -0.133068
# 26                   money_decide_person_someone else    -0.102890
#
#     abs_coeffient
# 20       1.031115
# 13       1.011025
# 14       1.004885
# 25       0.989633
# 12       0.941920
# 18       0.840583
# 9        0.814653
# 22       0.814487
# 10       0.808649
# 21       0.733161
# 16       0.719995
# 17       0.711268
# 8        0.709860
# 7        0.708585
# 11       0.657641
# 23       0.652304
# 28       0.647462
# 27       0.607680
# 24       0.588499
# 30       0.538736
# 31       0.462065
# 19       0.441827
# 15       0.439172
# 5        0.403288
# 6        0.350789
# 29       0.329259
# 3        0.258221
# 1        0.220539
# 2        0.210803
# 4        0.167712
# 0        0.133068
# 26       0.102890

# %%
pipeline_classification.plot_top10_attributes(coeffs, best_model)

# %% [markdown]
# ## Target 3: if have sexual violence

# %%
# Use SMOTE to deal with inbalanced data

result, best_model = pipeline_classification.train_logistic_regression_SMOTE(X_train, y_train3, 'All', 'if_sex_vio')

# %%
result
# Out:
#   country      target               model  \
# 0     All  if_sex_vio  LogisticRegression
# 1     All  if_sex_vio  LogisticRegression
# 2     All  if_sex_vio  LogisticRegression
# 3     All  if_sex_vio  LogisticRegression
# 4     All  if_sex_vio  LogisticRegression
#
#                                               params        f1  accuracy  \
# 0  {'logisticregression__C': 0.01, 'logisticregre...  0.141083  0.898388
# 1  {'logisticregression__C': 0.1, 'logisticregres...  0.071896  0.951172
# 2  {'logisticregression__C': 1, 'logisticregressi...  0.036062  0.957310
# 3  {'logisticregression__C': 10, 'logisticregress...  0.030001  0.957037
# 4  {'logisticregression__C': 100, 'logisticregres...  0.036062  0.957583
#
#    precision    recall   roc_auc
# 0   0.105734  0.215148  0.671449
# 1   0.140167  0.048645  0.655593
# 2   0.153333  0.020813  0.646600
# 3   0.128333  0.017365  0.640685
# 4   0.153333  0.020813  0.640405

# %%
best_model
# Out:
# LogisticRegression(C=0.01, random_state=0)

# %%
result1, best_model1 = pipeline_classification.train_logistic_regression(X_train, y_train3, 'All', 'if_sex_vio')

# %%
result1
# Out:
#   country      target               model                        params   f1  \
# 0     All  if_sex_vio  LogisticRegression  {'C': 0.01, 'penalty': 'l2'}  0.0
# 1     All  if_sex_vio  LogisticRegression   {'C': 0.1, 'penalty': 'l2'}  0.0
# 2     All  if_sex_vio  LogisticRegression     {'C': 1, 'penalty': 'l2'}  0.0
# 3     All  if_sex_vio  LogisticRegression    {'C': 10, 'penalty': 'l2'}  0.0
# 4     All  if_sex_vio  LogisticRegression   {'C': 100, 'penalty': 'l2'}  0.0
#
#    accuracy  precision  recall   roc_auc
# 0   0.96072        0.0     0.0  0.691227
# 1   0.96072        0.0     0.0  0.693136
# 2   0.96072        0.0     0.0  0.692227
# 3   0.96072        0.0     0.0  0.692038
# 4   0.96072        0.0     0.0  0.692044

# %%
best_model1
# Out:
# LogisticRegression(C=0.01, random_state=0)

# %% [raw]
# It's better to use the best model trained from the SMOTE LogisticRegression(C=0.01, random_state=0)

# %%
pipeline_classification.evaluate_test(best_model, X_test, y_test3, 0.5)
# Out:
# {'f1': 0.118,
#  'accuracy': 0.5190839694656488,
#  'precision': 0.064340239912759,
#  'recall': 0.7108433734939759,
#  'roc_auc': 0.6104188312358514,
#  'model_object': LogisticRegression(C=0.01, random_state=0)}

# %%
coeffs = pipeline_classification.get_important_attributes(X_train.columns, best_model)
coeffs
# Out:
#                                             predictor  coefficient  \
# 20                 partner_ideal_child_both want same    -1.306818
# 14                        if_earn_more_about the same    -1.301182
# 25  money_decide_person_respondent and husband/par...    -1.268047
# 13                               wealth_index_richest    -1.190730
# 28                                   country_Maldives    -1.184997
# 12                                wealth_index_richer    -1.169614
# 9                                 wealth_index_middle    -1.112968
# 21            partner_ideal_child_husband wants fewer    -1.092709
# 8                                      if_urban_urban    -1.089659
# 11                               wealth_index_poorest    -1.059429
# 16                         if_earn_more_less than him    -1.044402
# 7                                      if_urban_rural    -1.041012
# 18                          sex_head_household_female    -1.028273
# 17                         if_earn_more_more than him    -0.997646
# 10                                wealth_index_poorer    -0.958629
# 22             partner_ideal_child_husband wants more    -0.904671
# 23          money_decide_person_husband/partner alone    -0.780211
# 30                                   country_Pakistan    -0.745339
# 24               money_decide_person_respondent alone    -0.727932
# 27                                   country_Cambodia    -0.707885
# 19                            sex_head_household_male    -0.520784
# 15  if_earn_more_husband/partner doesn't bring in ...    -0.509963
# 5                                        if_own_house    -0.506505
# 29                                      country_Nepal    -0.372941
# 4                                         partner_edu    -0.286247
# 6                               if_employment_current    -0.281545
# 31                                country_Philippines    -0.261328
# 3                                           num_child     0.209208
# 2                                       num_household    -0.150321
# 1                                           education    -0.110059
# 0                                                 age    -0.083065
# 26                   money_decide_person_someone else    -0.074096
#
#     abs_coeffient
# 20       1.306818
# 14       1.301182
# 25       1.268047
# 13       1.190730
# 28       1.184997
# 12       1.169614
# 9        1.112968
# 21       1.092709
# 8        1.089659
# 11       1.059429
# 16       1.044402
# 7        1.041012
# 18       1.028273
# 17       0.997646
# 10       0.958629
# 22       0.904671
# 23       0.780211
# 30       0.745339
# 24       0.727932
# 27       0.707885
# 19       0.520784
# 15       0.509963
# 5        0.506505
# 29       0.372941
# 4        0.286247
# 6        0.281545
# 31       0.261328
# 3        0.209208
# 2        0.150321
# 1        0.110059
# 0        0.083065
# 26       0.074096

# %%
pipeline_classification.plot_top10_attributes(coeffs, best_model)

# %% [markdown]
# # Target 4: if have violence

# %%
# Use SMOTE to deal with inbalanced data

result, best_model = pipeline_classification.train_logistic_regression_SMOTE(X_train, y_train4, 'All', 'if_vio')

# %%
result
# Out:
#   country  target               model  \
# 0     All  if_vio  LogisticRegression
# 1     All  if_vio  LogisticRegression
# 2     All  if_vio  LogisticRegression
# 3     All  if_vio  LogisticRegression
# 4     All  if_vio  LogisticRegression
#
#                                               params        f1  accuracy  \
# 0  {'logisticregression__C': 0.01, 'logisticregre...  0.405476  0.669121
# 1  {'logisticregression__C': 0.1, 'logisticregres...  0.313716  0.714264
# 2  {'logisticregression__C': 1, 'logisticregressi...  0.252651  0.732679
# 3  {'logisticregression__C': 10, 'logisticregress...  0.235569  0.733361
# 4  {'logisticregression__C': 100, 'logisticregres...  0.234425  0.733361
#
#    precision    recall   roc_auc
# 0   0.356860  0.469886  0.642392
# 1   0.371430  0.272159  0.634936
# 2   0.386305  0.188636  0.632903
# 3   0.380008  0.171591  0.632504
# 4   0.378800  0.170455  0.632136

# %%
best_model
# Out:
# LogisticRegression(C=0.01, random_state=0)

# %%
pipeline_classification.evaluate_test(best_model, X_test, y_test4, 0.5)
# Out:
# {'f1': 0.41329479768786126,
#  'accuracy': 0.5572519083969466,
#  'precision': 0.311886586695747,
#  'recall': 0.6124197002141327,
#  'roc_auc': 0.5754124836110898,
#  'model_object': LogisticRegression(C=0.01, random_state=0)}

# %%
coeffs = pipeline_classification.get_important_attributes(X_train.columns, best_model)
coeffs
# Out:
#                                             predictor  coefficient  \
# 14                        if_earn_more_about the same    -0.856830
# 13                               wealth_index_richest    -0.769284
# 20                 partner_ideal_child_both want same    -0.756609
# 12                                wealth_index_richer    -0.643705
# 25  money_decide_person_respondent and husband/par...    -0.617113
# 18                          sex_head_household_female    -0.613481
# 22             partner_ideal_child_husband wants more    -0.590289
# 9                                 wealth_index_middle    -0.561150
# 17                         if_earn_more_more than him    -0.524017
# 8                                      if_urban_urban    -0.501790
# 28                                   country_Maldives    -0.476343
# 16                         if_earn_more_less than him    -0.475981
# 23          money_decide_person_husband/partner alone    -0.468528
# 7                                      if_urban_rural    -0.467353
# 10                                wealth_index_poorer    -0.453593
# 19                            sex_head_household_male    -0.450278
# 11                               wealth_index_poorest    -0.421570
# 29                                      country_Nepal    -0.413716
# 21            partner_ideal_child_husband wants fewer    -0.404720
# 27                                   country_Cambodia    -0.394745
# 24               money_decide_person_respondent alone    -0.366472
# 15  if_earn_more_husband/partner doesn't bring in ...    -0.361952
# 6                               if_employment_current    -0.332479
# 30                                   country_Pakistan    -0.299201
# 5                                        if_own_house    -0.276885
# 3                                           num_child     0.256260
# 1                                           education    -0.131213
# 4                                         partner_edu    -0.125086
# 2                                       num_household    -0.121334
# 0                                                 age    -0.120339
# 31                                country_Philippines    -0.098318
# 26                   money_decide_person_someone else    -0.085065
#
#     abs_coeffient
# 14       0.856830
# 13       0.769284
# 20       0.756609
# 12       0.643705
# 25       0.617113
# 18       0.613481
# 22       0.590289
# 9        0.561150
# 17       0.524017
# 8        0.501790
# 28       0.476343
# 16       0.475981
# 23       0.468528
# 7        0.467353
# 10       0.453593
# 19       0.450278
# 11       0.421570
# 29       0.413716
# 21       0.404720
# 27       0.394745
# 24       0.366472
# 15       0.361952
# 6        0.332479
# 30       0.299201
# 5        0.276885
# 3        0.256260
# 1        0.131213
# 4        0.125086
# 2        0.121334
# 0        0.120339
# 31       0.098318
# 26       0.085065

# %%
pipeline_classification.plot_top10_attributes(coeffs, best_model)

# %% [markdown]
# # Analyze Cambodia

# %%
X_train, X_test, y_train, y_test = pipeline_classification.prepare_data_contry\
                                  (df_Cambodia, features_col, target_col, dummy, need_one_hot, need_normalize)

y_train1, y_train2, y_train3, y_train4, y_test1, y_test2, y_test3, y_test4 = \
                                    pipeline_classification.name_target(y_train, y_test)

# %% [markdown]
# ## Target 1: if have emotional violence

# %%
result, eval, coeffs = pipeline_classification.analyze_country\
    (X_train, X_test, y_train1, y_test1, 'Cambodia', 'if_emo_vil', 0.5)

# %%
result
# Out:
#     country      target               model  \
# 0  Cambodia  if_emo_vil  LogisticRegression
# 1  Cambodia  if_emo_vil  LogisticRegression
# 2  Cambodia  if_emo_vil  LogisticRegression
# 3  Cambodia  if_emo_vil  LogisticRegression
# 4  Cambodia  if_emo_vil  LogisticRegression
#
#                                               params        f1  accuracy  \
# 0  {'logisticregression__C': 0.01, 'logisticregre...  0.366816  0.637190
# 1  {'logisticregression__C': 0.1, 'logisticregres...  0.322127  0.702231
# 2  {'logisticregression__C': 1, 'logisticregressi...  0.254791  0.752388
# 3  {'logisticregression__C': 10, 'logisticregress...  0.238750  0.763113
# 4  {'logisticregression__C': 100, 'logisticregres...  0.226955  0.762525
#
#    precision    recall   roc_auc
# 0   0.283182  0.523173  0.635470
# 1   0.301057  0.348663  0.626975
# 2   0.329850  0.209804  0.617242
# 3   0.339345  0.186096  0.615981
# 4   0.330799  0.174332  0.616420

# %%
eval
# Out:
# {'f1': 0.31272727272727274,
#  'accuracy': 0.548926014319809,
#  'precision': 0.20574162679425836,
#  'recall': 0.6515151515151515,
#  'roc_auc': 0.5906300970040346,
#  'model_object': LogisticRegression(C=0.01, random_state=0)}

# %%
coeffs[:10]
# Out:
#                                             predictor  coefficient  \
# 14                        if_earn_more_about the same    -0.435270
# 22             partner_ideal_child_husband wants more    -0.376337
# 25  money_decide_person_respondent and husband/par...    -0.336790
# 18                          sex_head_household_female    -0.316429
# 13                               wealth_index_richest    -0.275801
# 17                         if_earn_more_more than him    -0.269824
# 24               money_decide_person_respondent alone    -0.266969
# 12                                wealth_index_richer    -0.246558
# 4                                         partner_edu    -0.232224
# 6                               if_employment_current    -0.215259
#
#     abs_coeffient
# 14       0.435270
# 22       0.376337
# 25       0.336790
# 18       0.316429
# 13       0.275801
# 17       0.269824
# 24       0.266969
# 12       0.246558
# 4        0.232224
# 6        0.215259

# %% [markdown]
# ## Target 2: if have physical violence

# %%
result, eval, coeffs = pipeline_classification.analyze_country\
    (X_train, X_test, y_train2, y_test2, 'Cambodia', 'if_phy_vil', 0.5)

# %%
result
# Out:
#     country      target               model  \
# 0  Cambodia  if_phy_vil  LogisticRegression
# 1  Cambodia  if_phy_vil  LogisticRegression
# 2  Cambodia  if_phy_vil  LogisticRegression
# 3  Cambodia  if_phy_vil  LogisticRegression
# 4  Cambodia  if_phy_vil  LogisticRegression
#
#                                               params        f1  accuracy  \
# 0  {'logisticregression__C': 0.01, 'logisticregre...  0.290338  0.671225
# 1  {'logisticregression__C': 0.1, 'logisticregres...  0.244585  0.754748
# 2  {'logisticregression__C': 1, 'logisticregressi...  0.229782  0.815608
# 3  {'logisticregression__C': 10, 'logisticregress...  0.207232  0.823385
# 4  {'logisticregression__C': 100, 'logisticregres...  0.197748  0.824579
#
#    precision    recall   roc_auc
# 0   0.203262  0.511472  0.656373
# 1   0.208289  0.301082  0.643347
# 2   0.260377  0.209740  0.634651
# 3   0.264729  0.173377  0.630489
# 4   0.255688  0.164286  0.630133

# %%
eval
# Out:
# {'f1': 0.2957198443579767,
#  'accuracy': 0.568019093078759,
#  'precision': 0.18181818181818182,
#  'recall': 0.7916666666666666,
#  'roc_auc': 0.6653751123090745,
#  'model_object': LogisticRegression(C=0.01, random_state=0)}

# %%
coeffs[:10]
# Out:
#                                             predictor  coefficient  \
# 14                        if_earn_more_about the same    -0.572247
# 25  money_decide_person_respondent and husband/par...    -0.454613
# 1                                           education    -0.433722
# 18                          sex_head_household_female    -0.413129
# 22             partner_ideal_child_husband wants more    -0.401132
# 17                         if_earn_more_more than him    -0.349320
# 13                               wealth_index_richest    -0.337879
# 9                                 wealth_index_middle    -0.324889
# 20                 partner_ideal_child_both want same    -0.304944
# 12                                wealth_index_richer    -0.303821
#
#     abs_coeffient
# 14       0.572247
# 25       0.454613
# 1        0.433722
# 18       0.413129
# 22       0.401132
# 17       0.349320
# 13       0.337879
# 9        0.324889
# 20       0.304944
# 12       0.303821

# %% [markdown]
# ## Target 3: if have sexual violence

# %%
result, eval, coeffs = pipeline_classification.analyze_country\
    (X_train, X_test, y_train3, y_test3, 'Cambodia', 'if_sex_vio', 0.5)

# %% [markdown]
# ## Target 4: if have violence

# %%
result, eval, coeffs = pipeline_classification.analyze_country\
    (X_train, X_test, y_train4, y_test4, 'Cambodia', 'if_sex_vio', 0.5)

# %% [markdown]
# # Analyze all countries by GaussianNB

# %%
X_train, X_test, y_train, y_test = pipeline_classification.prepare_data_contry\
        (df, features_col, target_col, dummy, need_one_hot, need_normalize, True)

# %%
y_train1, y_train2, y_train3, y_train4, y_test1, y_test2, y_test3, y_test4=\
        pipeline_classification.name_target(y_train, y_test)

# %% [markdown]
# ## Target 1: if have emotional violence

# %%
result, eval, coeffs = pipeline_classification.analyze_country\
    (X_train, X_test, y_train1, y_test1, 'All', 'if_emo_vil', 0.5)

# %%
result
# Out:
#   country      target               model  \
# 0     All  if_emo_vil  LogisticRegression
# 1     All  if_emo_vil  LogisticRegression
# 2     All  if_emo_vil  LogisticRegression
# 3     All  if_emo_vil  LogisticRegression
# 4     All  if_emo_vil  LogisticRegression
#
#                                               params        f1  accuracy  \
# 0  {'logisticregression__C': 0.01, 'logisticregre...  0.336219  0.681126
# 1  {'logisticregression__C': 0.1, 'logisticregres...  0.244449  0.747000
# 2  {'logisticregression__C': 1, 'logisticregressi...  0.197736  0.770186
# 3  {'logisticregression__C': 10, 'logisticregress...  0.180514  0.770595
# 4  {'logisticregression__C': 100, 'logisticregres...  0.183977  0.771004
#
#    precision    recall   roc_auc
# 0   0.282433  0.415902  0.618585
# 1   0.292847  0.210411  0.609183
# 2   0.310621  0.145671  0.604824
# 3   0.297711  0.130198  0.603961
# 4   0.301742  0.133015  0.603577

# %%
eval
# Out:
# {'f1': 0.34937888198757766,
#  'accuracy': 0.5430752453653217,
#  'precision': 0.24536532170119957,
#  'recall': 0.6064690026954178,
#  'roc_auc': 0.5667341595842093,
#  'model_object': LogisticRegression(C=0.01, random_state=0)}

# %%
coeffs[:10]
# Out:
#                                             predictor  coefficient  \
# 13                               wealth_index_richest    -0.997101
# 14                        if_earn_more_about the same    -0.899601
# 12                                wealth_index_richer    -0.800193
# 18                          sex_head_household_female    -0.737858
# 20                 partner_ideal_child_both want same    -0.732476
# 9                                 wealth_index_middle    -0.730877
# 25  money_decide_person_respondent and husband/par...    -0.668331
# 22             partner_ideal_child_husband wants more    -0.657275
# 8                                      if_urban_urban    -0.627151
# 17                         if_earn_more_more than him    -0.607701
#
#     abs_coeffient
# 13       0.997101
# 14       0.899601
# 12       0.800193
# 18       0.737858
# 20       0.732476
# 9        0.730877
# 25       0.668331
# 22       0.657275
# 8        0.627151
# 17       0.607701

# %% [markdown]
# ## Target 2: if have physical violence

# %%
result, eval, coeffs = pipeline_classification.analyze_country\
    (X_train, X_test, y_train2, y_test2, 'All', 'if_phy_vil', 0.5)

# %% [markdown]
# ## Target 3: if have sexual violence

# %%
result, eval, coeffs = pipeline_classification.analyze_country\
    (X_train, X_test, y_train3, y_test3, 'All', 'if_sex_vil', 0.5)

# %% [markdown]
# ## Target 4: if have violence

# %%
result, eval, coeffs = pipeline_classification.analyze_country\
    (X_train, X_test, y_train4, y_test4, 'All', 'if_vil', 0.5)
